# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pylab as plt
from mpl_toolkits.mplot3d import Axes3D
from thomson import *

# %%
npts = 5000
theta, phi = fib_sphere_grid(npts)
x, y, z = thetaphi2xyz(theta, phi)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x,y,z)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
indx=2000
xn,yn,zn = minimize_single(x,y,z, indx)

# %%
xn,yn,zn
# Out:
# (array([-0.84632609]), array([-0.49375572]), array([-0.19984355]))

# %%
x[indx], y[indx], z[indx]
# Out:
# (-0.84636357103462412, -0.49370909007787034, -0.19980000000000001)

# %%
# Out:
# array([ 1.])
