# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pylab as plt
from mpl_toolkits.mplot3d import Axes3D
from spiral import *
from thomson import *
import healpy as hp
from lsst.sims.utils import _healbin

# %%
theta, phi = npts2thetaphi(6000)

# %%
x,y,z = thetaphi2xyz(theta, phi)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x,y,z, s=1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
nside=8
theta, phi = xyz2thetaphi(x, y, z)
density = _healbin(theta, phi-np.pi/2, theta*0+1, nside=nside, reduceFunc=np.sum)
hp.mollview(density, unit='Number of points', title='ack')
# Out:
# <img src="data:image/png;base64,..." width="850">
