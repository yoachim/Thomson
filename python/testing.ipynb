# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pylab as plt
from mpl_toolkits.mplot3d import Axes3D
from thomson import *
from lsst.sims.utils import _healbin
import healpy as hp
from lsst.sims.featureScheduler import read_fields

# %%
npts = 5000
theta, phi = fib_sphere_grid(npts)
# Note, declination = phi - pi/2, RA = theta
x, y, z = thetaphi2xyz(theta, phi)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x,y,z)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
nside = 16
density = _healbin(theta, phi-np.pi/2, theta*0+1, nside=nside, reduceFunc=np.sum)
hp.mollview(density, unit='Number of points', title='Fibonacci Spiral')
# Out:
# <img src="data:image/png;base64,..." width="850">

# %%
indx=200
xn,yn,zn = minimize_single(x,y,z, indx)

# %%
xn,yn,zn
# Out:
# (array([-0.21234449]), array([-0.33963003]), array([-0.91627576]))

# %%
x[indx], y[indx], z[indx]
# Out:
# (-0.20673090839200248, -0.33351205602709122, -0.91979999999999995)

# %%
fields = read_fields()

# %%
nside=16
density = _healbin(fields['RA'], fields['dec'], fields['RA']*0+1, nside=nside, reduceFunc=np.sum)
hp.mollview(density, unit='Number of points', title='Hexpack Tesselation')
# Out:
# <img src="data:image/png;base64,..." width="850">
